# %% [markdown]
# # Simplifying the mianserin worm data
#
# Tong Shu Li
#
# In this notebook, we will:
#
# 1. Remove genes which did not have drift values for all three replicates in all three samples.
# 2. Average the drift and expression values observed in the different biological replicates.

# %%
import pandas as pd
import numpy as np

from functools import reduce

# %% [markdown]
# ---

# %% [markdown]
# ## Read the full annotated data

# %%
full = pd.read_csv("annotated_cpm_values.tsv", sep = '\t')

# %%
full.head(10)
# Out:
#   seqname  samples     value  cohort  replicate  day_harvested   drug  \
# 0  2L52.1       11  3.486620       1          1              1  water
# 1  2L52.1       12  0.963996       1          2              1  water
# 2  2L52.1       13  0.886719       1          3              1  water
# 3  2L52.1       21  3.529880       2          1              3  water
# 4  2L52.1       22  3.392530       2          2              3  water
# 5  2L52.1       23  4.195730       2          3              3  water
# 6  2L52.1       31  1.649990       3          1              5  water
# 7  2L52.1       32  2.833490       3          2              5  water
# 8  2L52.1       33  3.108170       3          3              5  water
# 9  2L52.1       41  2.663960       4          1             10  water
#
#    drug_conc_uM  day_drug_added  youngref  trans_drift      wormbaseid  \
# 0             0               1  1.779111     0.672818  WBGene00007063
# 1             0               1  1.779111    -0.612782  WBGene00007063
# 2             0               1  1.779111    -0.696341  WBGene00007063
# 3             0               1  1.779111     0.685150  WBGene00007063
# 4             0               1  1.779111     0.645462  WBGene00007063
# 5             0               1  1.779111     0.857953  WBGene00007063
# 6             0               1  1.779111    -0.075347  WBGene00007063
# 7             0               1  1.779111     0.465397  WBGene00007063
# 8             0               1  1.779111     0.557920  WBGene00007063
# 9             0               1  1.779111     0.403698  WBGene00007063
#
#   gene_symbol
# 0      2L52.1
# 1      2L52.1
# 2      2L52.1
# 3      2L52.1
# 4      2L52.1
# 5      2L52.1
# 6      2L52.1
# 7      2L52.1
# 8      2L52.1
# 9      2L52.1

# %%
full.shape
# Out:
# (690084, 13)

# %% [markdown]
# ## Explore the data

# %%
# number of unique genes
len(full["seqname"].unique())
# Out:
# 19169

# %%
# check that the full transcriptome was measured for each replicate of each sample
full.groupby(["cohort", "replicate"]).apply(
    lambda f: len(f["seqname"].unique())
)
# Out:
# cohort  replicate
# 1       1            19169
#         2            19169
#         3            19169
# 2       1            19169
#         2            19169
#         3            19169
# 3       1            19169
#         2            19169
#         3            19169
# 4       1            19169
#         2            19169
#         3            19169
# 5       1            19169
#         2            19169
#         3            19169
# 6       1            19169
#         2            19169
#         3            19169
# 7       1            19169
#         2            19169
#         3            19169
# 8       1            19169
#         2            19169
#         3            19169
# 9       1            19169
#         2            19169
#         3            19169
# 10      1            19169
#         2            19169
#         3            19169
# 11      1            19169
#         2            19169
#         3            19169
# 12      1            19169
#         2            19169
#         3            19169
# dtype: int64

# %%
# in each sample, how many genes were missing drift values?
full.groupby(["cohort", "replicate"]).apply(
    lambda f: f["trans_drift"].isnull().sum()
)
# Out:
# cohort  replicate
# 1       1            2857
#         2            4392
#         3            2899
# 2       1            2406
#         2            2705
#         3            2746
# 3       1            2231
#         2            2847
#         3            2014
# 4       1            2154
#         2            3831
#         3            1922
# 5       1            3068
#         2            3618
#         3            2991
# 6       1            2754
#         2            5020
#         3            2981
# 7       1            3104
#         2            3451
#         3            2824
# 8       1            3011
#         2            3680
#         3            2593
# 9       1            2095
#         2            2767
#         3            2322
# 10      1            2846
#         2            2831
#         3            2258
# 11      1            3308
#         2            2075
#         3            1913
# 12      1            3192
#         2            6089
#         3            2568
# dtype: int64

# %%
# provide some statistics about genes missing drift values
full.groupby(["cohort", "replicate"]).apply(
    lambda f: f["trans_drift"].isnull().sum()
).describe()
# Out:
# count      36.000000
# mean     2954.527778
# std       858.373129
# min      1913.000000
# 25%      2385.000000
# 50%      2838.500000
# 75%      3126.000000
# max      6089.000000
# dtype: float64

# %% [markdown]
# So some genes are missing drift values in some samples. Let's check how many genes are missing in all samples, and how many are missing in at least one sample.

# %%
missing_genes = {
    info: set(df[df["trans_drift"].isnull()]["seqname"])
    for info, df in full.groupby(["cohort", "replicate"])
}

print("# unique genes with no drift value in all samples:",
    len(reduce(lambda x, y: x & y, missing_genes.values()))
)

print("# unique genes with no drift value in any sample:",
    len(reduce(lambda x, y: x | y, missing_genes.values()))
)
# Out:
# # unique genes with no drift value in all samples: 1653
# # unique genes with no drift value in any sample: 8290

# %% [markdown]
# Although we measured the expression values for all 19169 genes, we do not have the drift values for 1653 genes in all 36 samples. This means that either the value of expression or the young reference for that gene was 0.
#
# We will need to exclude these genes from our analysis, since they provide us with no information.

# %% [markdown]
# ---

# %% [markdown]
# ## Discard any genes which have no drift value in any sample
#
# Since we want to be consistent, with three replicates for each measurement, we will discard any genes which are missing in **any** sample.

# %%
bad_genes = reduce(lambda x, y: x | y, missing_genes.values())
good_genes = set(full["seqname"]) - bad_genes

temp = pd.DataFrame({"seqname": list(good_genes)})

good = pd.merge(temp, full, how = "left", on = "seqname")

# %%
good.shape
# Out:
# (391644, 13)

# %%
good.head(10)
# Out:
#    seqname  samples     value  cohort  replicate  day_harvested   drug  \
# 0  C30G4.4       11  1.206910       1          1              1  water
# 1  C30G4.4       12  0.963996       1          2              1  water
# 2  C30G4.4       13  0.886719       1          3              1  water
# 3  C30G4.4       21  1.764940       2          1              3  water
# 4  C30G4.4       22  0.502597       2          2              3  water
# 5  C30G4.4       23  1.284410       2          3              3  water
# 6  C30G4.4       31  2.024980       3          1              5  water
# 7  C30G4.4       32  0.386386       3          2              5  water
# 8  C30G4.4       33  1.874770       3          3              5  water
# 9  C30G4.4       41  2.024610       4          1             10  water
#
#    drug_conc_uM  day_drug_added  youngref  trans_drift      wormbaseid  \
# 0             0               1  1.019207     0.169035  WBGene00016269
# 1             0               1  1.019207    -0.055693  WBGene00016269
# 2             0               1  1.019207    -0.139252  WBGene00016269
# 3             0               1  1.019207     0.549092  WBGene00016269
# 4             0               1  1.019207    -0.706992  WBGene00016269
# 5             0               1  1.019207     0.231272  WBGene00016269
# 6             0               1  1.019207     0.686536  WBGene00016269
# 7             0               1  1.019207    -0.969944  WBGene00016269
# 8             0               1  1.019207     0.609460  WBGene00016269
# 9             0               1  1.019207     0.686350  WBGene00016269
#
#   gene_symbol
# 0     C30G4.4
# 1     C30G4.4
# 2     C30G4.4
# 3     C30G4.4
# 4     C30G4.4
# 5     C30G4.4
# 6     C30G4.4
# 7     C30G4.4
# 8     C30G4.4
# 9     C30G4.4

# %%
# number of unique genes now
len(good["seqname"].unique())
# Out:
# 10879

# %% [markdown]
# We have effectively reduced the number of genes we are measuring from 19169 to 10879, which is around half the size.

# %% [markdown]
# ## Average drift values across replicates
#
# For further plotting, we will ignore the fact that multiple batches exist. We will take the mean of the drift values for each gene for each sample.

# %%
avg = good.drop(["samples", "replicate"], axis = 1).groupby(["seqname", "cohort"], as_index = False).agg(np.mean)

# add back in the metadata columns
metadata = good[["seqname", "cohort", "drug", "wormbaseid", "gene_symbol"]].drop_duplicates()

avg = pd.merge(avg, metadata, on = ["seqname", "cohort"], how = "inner")
avg = avg.rename(columns = {"cohort": "sample"})

# %%
avg.head(20)
# Out:
#     seqname  sample     value  day_harvested  drug_conc_uM  day_drug_added  \
# 0   2RSSE.1       1  4.105727              1             0               1
# 1   2RSSE.1       2  7.687213              3             0               1
# 2   2RSSE.1       3  7.220500              5             0               1
# 3   2RSSE.1       4  3.923197             10             0               1
# 4   2RSSE.1       5  4.042023              3            50               1
# 5   2RSSE.1       6  2.934010              5            50               1
# 6   2RSSE.1       7  3.966477             10            50               1
# 7   2RSSE.1       8  4.658657              5            50               3
# 8   2RSSE.1       9  3.888840             10            50               3
# 9   2RSSE.1      10  2.733700             10            50               5
# 10  2RSSE.1      11  4.972573              5             2               1
# 11  2RSSE.1      12  4.088217              5            10               1
# 12    3R5.1       1  2.706673              1             0               1
# 13    3R5.1       2  2.205293              3             0               1
# 14    3R5.1       3  2.117057              5             0               1
# 15    3R5.1       4  3.790973             10             0               1
# 16    3R5.1       5  2.240050              3            50               1
# 17    3R5.1       6  2.091763              5            50               1
# 18    3R5.1       7  4.015090             10            50               1
# 19    3R5.1       8  2.061747              5            50               3
#
#     youngref  trans_drift       drug      wormbaseid gene_symbol
# 0   4.105726    -0.012915      water  WBGene00007064     2RSSE.1
# 1   4.105726     0.562429      water  WBGene00007064     2RSSE.1
# 2   4.105726     0.562490      water  WBGene00007064     2RSSE.1
# 3   4.105726    -0.049039      water  WBGene00007064     2RSSE.1
# 4   4.105726    -0.030335  mianserin  WBGene00007064     2RSSE.1
# 5   4.105726    -0.490734  mianserin  WBGene00007064     2RSSE.1
# 6   4.105726    -0.126457  mianserin  WBGene00007064     2RSSE.1
# 7   4.105726     0.091843  mianserin  WBGene00007064     2RSSE.1
# 8   4.105726    -0.057390  mianserin  WBGene00007064     2RSSE.1
# 9   4.105726    -0.477487  mianserin  WBGene00007064     2RSSE.1
# 10  4.105726     0.178805  mianserin  WBGene00007064     2RSSE.1
# 11  4.105726    -0.035141  mianserin  WBGene00007064     2RSSE.1
# 12  2.706671    -0.003040      water  WBGene00007065       pot-3
# 13  2.706671    -0.208088      water  WBGene00007065       pot-3
# 14  2.706671    -0.258914      water  WBGene00007065       pot-3
# 15  2.706671     0.312946      water  WBGene00007065       pot-3
# 16  2.706671    -0.229026  mianserin  WBGene00007065       pot-3
# 17  2.706671    -0.294364  mianserin  WBGene00007065       pot-3
# 18  2.706671     0.361945  mianserin  WBGene00007065       pot-3
# 19  2.706671    -0.337090  mianserin  WBGene00007065       pot-3

# %%
avg.shape
# Out:
# (130548, 11)

# %% [markdown]
# We now have a cleaned dataframe containing the averaged expression and drift values for 10879 genes for all samples and conditions.

# %% [markdown]
# ## Save cleaned data to file

# %%
avg.to_csv("avg_annotated_cpm_values.tsv", sep = '\t', index = False)
